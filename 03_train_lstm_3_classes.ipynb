# %%
import os
import numpy as np
from pathlib import Path
from typing import List, Tuple
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf

# %% [markdown]
# ## 1. Load and Preprocess Data

# %%
# ---- Config ----
DATA_DIR = Path("MP_Videos_All_keyframes_3_classes/")   # your collected keypoints live here
SEQ_LEN  = 60                # frames per sequence expected by the LSTM
SAVE_DIR = Path("artifacts_3_classes") # where to persist preprocessed arrays
SAVE_DIR.mkdir(parents=True, exist_ok=True)

# ---- Discover action classes from directory names ----
places: List[str] = sorted([p.name for p in DATA_DIR.iterdir() if p.is_dir()])
if not places:
    raise RuntimeError(f"No action folders found in {DATA_DIR.resolve()}")
print("Detected places:", places)
# Out:
# Detected places: ['Bedok', 'City Hall', 'MBS']

# %% [markdown]
# ## 2. Prepare Training and Testing Data

# %%
# ---- Helpers ----
def load_sequence(seq_dir: Path, expected_len: int = SEQ_LEN) -> np.ndarray:
    """
    Load all .npy frames in a sequence folder, sort by filename, and
    pad/truncate to expected_len. Each frame must be a 1D vector (e.g. 1662,).
    Returns shape: (expected_len, F) float32.
    """
    frame_files = sorted([p for p in seq_dir.iterdir() if p.suffix == ".npy"])
    frames = []
    for f in frame_files[:expected_len]:
        arr = np.load(f)
        if arr.ndim != 1:
            raise ValueError(f"Frame {f} has shape {arr.shape}; expected (F,)")
        frames.append(arr.astype(np.float32, copy=False))
    # infer feature dim (F)
    if frames:
        F = frames[0].shape[0]
    else:
        # If the sequence folder is empty, fall back to 1662 (your legacy size)
        F = 1662
    # pad if too short
    if len(frames) < expected_len:
        pad = [np.zeros((F,), dtype=np.float32) for _ in range(expected_len - len(frames))]
        frames.extend(pad)
    # truncate if too long
    frames = frames[:expected_len]
    seq = np.stack(frames, axis=0)  # (T, F)
    return seq

def iter_sequences(data_root: Path) -> Tuple[List[np.ndarray], List[str]]:
    X_list, y_list = [], []
    for action in places:
        action_dir = data_root / action
        # sequence folders under each action (e.g., "0", "1", ...)
        seq_dirs = sorted([p for p in action_dir.iterdir() if p.is_dir()],
                          key=lambda p: p.name)
        for sd in seq_dirs:
            try:
                seq = load_sequence(sd, SEQ_LEN)
                # sanity: finite values only
                if not np.isfinite(seq).all():
                    continue
                X_list.append(seq)
                y_list.append(action)
            except Exception as e:
                # Skip corrupted sequences but continue
                print(f"[WARN] Skipping {sd}: {e}")
    return X_list, y_list

# ---- Load all sequences ----
X_list, y_list = iter_sequences(DATA_DIR)
if not X_list:
    raise RuntimeError("No valid sequences found. Check your data folders.")

X = np.stack(X_list, axis=0).astype(np.float32)  # (N, T, F)
print("X shape:", X.shape)

# ---- Encode labels (int -> one-hot) ----
le = LabelEncoder()
y_int = le.fit_transform(y_list)                       # (N,)
num_classes = len(le.classes_)
y = tf.keras.utils.to_categorical(y_int, num_classes)  # (N, C)
print("Classes:", list(le.classes_))
print("y (one-hot) shape:", y.shape)

# ---- Stratified train/val/test split (80/10/10) ----
X_train, X_tmp, y_train, y_tmp, yi_train, yi_tmp = train_test_split(
    X, y, y_int, test_size=0.20, random_state=42, stratify=y_int
)
X_val, X_test, y_val, y_test, yi_val, yi_test = train_test_split(
    X_tmp, y_tmp, yi_tmp, test_size=0.50, random_state=42, stratify=yi_tmp
)

print(
    f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape} | "
    f"Classes={num_classes}"
)

# ---- Optional: class distribution report ----
def dist(name, yi):
    unique, counts = np.unique(yi, return_counts=True)
    print(name, dict(zip(le.inverse_transform(unique), counts.tolist())))

dist("Train dist:", yi_train)
dist("Val   dist:", yi_val)
dist("Test  dist:", yi_test)

# ---- Persist for later sections ----
np.savez_compressed(SAVE_DIR / "dataset_train.npz", X=X_train, y=y_train)
np.savez_compressed(SAVE_DIR / "dataset_val.npz",   X=X_val,   y=y_val)
np.savez_compressed(SAVE_DIR / "dataset_test.npz",  X=X_test,  y=y_test)

# ---- Handy accessors if you prefer variables in-memory for the next cell ----
classes = le.classes_.tolist()
feature_dim = X.shape[-1]
print("classes:", classes)
print("feature_dim:", feature_dim)
# Out:
# X shape: (90, 60, 258)
# Classes: ['Bedok', 'City Hall', 'MBS']
# y (one-hot) shape: (90, 3)
# Train: (72, 60, 258), Val: (9, 60, 258), Test: (9, 60, 258) | Classes=3
# Train dist: {'Bedok': 24, 'City Hall': 24, 'MBS': 24}
# Val   dist: {'Bedok': 3, 'City Hall': 3, 'MBS': 3}
# Test  dist: {'Bedok': 3, 'City Hall': 3, 'MBS': 3}
# classes: ['Bedok', 'City Hall', 'MBS']
# feature_dim: 258

# %% [markdown]
# ## 3. LSTM Training

# %%
ARTIFACTS = Path("artifacts_3_classes"); ARTIFACTS.mkdir(parents=True, exist_ok=True)

# TensorBoard logs directory (timestamped run folder)
from datetime import datetime
TB_ROOT = ARTIFACTS / "tb_logs" / "train"
TB_ROOT.mkdir(parents=True, exist_ok=True)
LOG_DIR = TB_ROOT / datetime.now().strftime("%Y%m%d-%H%M%S")

seq_len, feature_dim = int(X_train.shape[1]), int(X_train.shape[2])
num_classes = int(y_train.shape[1])
assert num_classes >= 2, "Need at least 2 classes."

# --- sample weights (class balancing) ---
yi_train = np.argmax(y_train, axis=1)
counts = np.bincount(yi_train, minlength=num_classes).astype(np.float64)
inv_freq = (counts.sum() / (counts + 1e-12)) / num_classes
sample_weights = inv_freq[yi_train].astype(np.float32)

def make_ds(X, y, sw=None, batch=64, shuffle=False):
    if sw is None:
        ds = tf.data.Dataset.from_tensor_slices((X, y))
    else:
        ds = tf.data.Dataset.from_tensor_slices((X, y, sw))
    if shuffle:
        ds = ds.shuffle(min(len(X), 1000), seed=42, reshuffle_each_iteration=True)
    return ds.batch(batch).prefetch(tf.data.AUTOTUNE)

train_ds = make_ds(X_train, y_train, sample_weights, shuffle=True)
val_ds   = make_ds(X_val,   y_val)
test_ds  = make_ds(X_test,  y_test)

# ================= MODEL =================
inputs = tf.keras.Input(shape=(seq_len, feature_dim))

# OPTION A (safest & fastest): **NO Masking** (just pass zeros through)
x = inputs

# If you strongly want masking, use OPTION B instead and comment out OPTION A.
# OPTION B: keep masking but avoid cuDNN kernels that reject non-right-padded masks
# x = tf.keras.layers.Masking(mask_value=0.0)(inputs)

x = tf.keras.layers.LSTM(128, return_sequences=True,  use_cudnn=False)(x)  # <— cuDNN off
x = tf.keras.layers.Dropout(0.30)(x)
x = tf.keras.layers.LSTM(64,  return_sequences=False, use_cudnn=False)(x)  # <— cuDNN off
x = tf.keras.layers.Dropout(0.30)(x)

x = tf.keras.layers.Dense(128, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.30)(x)
outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

model = tf.keras.Model(inputs, outputs)

# dynamic metrics (avoid TopK crash when classes < k)
metrics = ["accuracy"]
k_top = min(3, num_classes)
if k_top >= 2:
    metrics.append(tf.keras.metrics.TopKCategoricalAccuracy(k=k_top, name=f"top{k_top}_acc"))

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=metrics,
)

ckpt_path = ARTIFACTS / "action_lstm.keras"
# TensorBoard callback (profile_batch=0 to avoid profiler overhead)
tb_cb = tf.keras.callbacks.TensorBoard(log_dir=str(LOG_DIR), histogram_freq=1, profile_batch=0)

cbs = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=6, min_lr=1e-5),
    tf.keras.callbacks.ModelCheckpoint(filepath=str(ckpt_path), monitor="val_accuracy", save_best_only=True),
    tf.keras.callbacks.CSVLogger(str(ARTIFACTS / "training_log.csv")),
    tb_cb,
]

history = model.fit(train_ds, validation_data=val_ds, epochs=2000, callbacks=cbs, verbose=1)

best = tf.keras.models.load_model(str(ckpt_path))
results = best.evaluate(test_ds, verbose=0)
print("Eval metrics:", dict(zip(best.metrics_names, [float(r) for r in results])))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761653341.219111 69859699 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1761653341.219144 69859699 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 9s/step - accuracy: 0.3889 - loss: 1.8231 - top3_acc: 1.0000 - val_accuracy: 0.3333 - val_loss: 1.1190 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 2/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 0.3472 - loss: 1.4336 - top3_acc: 1.0000 - val_accuracy: 0.3333 - val_loss: 1.1554 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 3/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 0.5139 - loss: 1.2351 - top3_acc: 1.0000 - val_accuracy: 0.3333 - val_loss: 1.1054 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 4/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 8s/step - accuracy: 0.4861 - loss: 1.3338 - top3_acc: 1.0000 - val_accuracy: 0.4444 - val_loss: 1.0585 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 5/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - accuracy: 0.4583 - loss: 1.3756 - top3_acc: 1.0000 - val_accuracy: 0.5556 - val_loss: 1.0320 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 6/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - accuracy: 0.4861 - loss: 1.2570 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.9845 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 7/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.5972 - loss: 1.1103 - top3_acc: 1.0000 - val_accuracy: 0.4444 - val_loss: 0.9699 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 8/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.7083 - loss: 0.8143 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.8185 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 9/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 0.6389 - loss: 0.7008 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.7666 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 10/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 0.7361 - loss: 0.7361 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.7243 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 11/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6528 - loss: 0.6337 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.7098 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 12/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.7917 - loss: 0.4555 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.7340 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 13/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.7639 - loss: 0.6045 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.7914 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 14/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.7083 - loss: 0.6733 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.7290 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 15/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.7778 - loss: 0.4528 - top3_acc: 1.0000 - val_accuracy: 0.5556 - val_loss: 0.9105 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 16/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6528 - loss: 0.8252 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.8104 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 17/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8333 - loss: 0.3965 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.7161 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 18/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.8194 - loss: 0.4164 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.7011 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 19/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.7222 - loss: 0.6221 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.6818 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 20/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8056 - loss: 0.4373 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.6537 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 21/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8194 - loss: 0.4549 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.6124 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 22/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8611 - loss: 0.3384 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.5630 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 23/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8750 - loss: 0.3796 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.5332 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 24/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8611 - loss: 0.4168 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.5251 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 25/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.8194 - loss: 0.4008 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.5130 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 26/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9167 - loss: 0.2809 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.4803 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 27/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.8750 - loss: 0.2944 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.4567 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 28/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9167 - loss: 0.3005 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.4310 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 29/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9167 - loss: 0.3172 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3857 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 30/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9444 - loss: 0.1993 - top3_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.4202 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 31/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9583 - loss: 0.1910 - top3_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.4214 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 32/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9028 - loss: 0.2876 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.4045 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 33/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.9306 - loss: 0.2466 - top3_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.2975 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 34/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9722 - loss: 0.1042 - top3_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.3745 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 35/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9583 - loss: 0.1467 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3306 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 36/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9028 - loss: 0.3271 - top3_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.2578 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 37/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9861 - loss: 0.1174 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.5629 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 38/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8333 - loss: 0.3923 - top3_acc: 1.0000 - val_accuracy: 0.6667 - val_loss: 0.4346 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 39/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.9306 - loss: 0.1780 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.4005 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 40/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.9306 - loss: 0.2347 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.4313 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 41/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.8750 - loss: 0.2452 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.4215 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 42/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9306 - loss: 0.1569 - top3_acc: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.3923 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 43/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9444 - loss: 0.1672 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3691 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 44/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.9583 - loss: 0.1645 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3643 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 45/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9306 - loss: 0.1866 - top3_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.3558 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 46/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.9306 - loss: 0.1993 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3549 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 47/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.9722 - loss: 0.1063 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3461 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 48/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.9861 - loss: 0.0636 - top3_acc: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3237 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Eval metrics: {'loss': 0.5467074513435364, 'compile_metrics': 0.7777777910232544}

# %% [markdown]
# ## 5. Save Weights

# %%
import json
import numpy as np
import tensorflow as tf
from pathlib import Path

ARTIFACTS = Path("artifacts_3_classes")
ARTIFACTS.mkdir(parents=True, exist_ok=True)

# 1) Save the *best* model in Keras native format (.keras)
BEST_MODEL = ARTIFACTS / "action_lstm.keras"         # from ModelCheckpoint in Section 7
if not BEST_MODEL.exists():
    # If you didn't use a checkpoint callback, fall back to the current in-memory model
    BEST_MODEL = ARTIFACTS / "action_lstm_v1.keras"
    model.save(str(BEST_MODEL))
else:
    # Ensure file is valid by reloading once
    _ = tf.keras.models.load_model(str(BEST_MODEL))

print(f"Saved model: {BEST_MODEL}")

# 2) (Optional) Also save *weights only* (useful for quick swaps / debugging)
WEIGHTS_PATH = ARTIFACTS / "action_lstm_v1.weights.h5"
model.save_weights(str(WEIGHTS_PATH))
print(f"Saved weights: {WEIGHTS_PATH}")

# 3) Persist class names & basic metadata for inference
meta = {
    "classes": classes if 'classes' in globals() else [f"class_{i}" for i in range(int(y_train.shape[1]))],
    "seq_len": int(X_train.shape[1]),
    "feature_dim": int(X_train.shape[2]),
    "framework": "tf.keras",
}
with open(ARTIFACTS / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)
np.save(ARTIFACTS / "classes.npy", np.array(meta["classes"], dtype=object))  # convenience for numpy loaders
print("Saved meta: artifacts/meta.json and artifacts/classes.npy")

# 4) (Optional) Export a portable TFLite model for on-device inference
try:
    best_model = tf.keras.models.load_model(str(BEST_MODEL))
    converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
    # If you want a small model, uncomment dynamic range quantization:
    # converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite = converter.convert()
    TFLITE_PATH = ARTIFACTS / "action_lstm_v1.tflite"
    with open(TFLITE_PATH, "wb") as f:
        f.write(tflite)
    print(f"Saved TFLite model: {TFLITE_PATH}")
except Exception as e:
    print(f"[WARN] TFLite export skipped: {e}")

# 5) (Optional) Save training history has already been logged by CSVLogger in Section 7:
#   artifacts/training_log.csv
# Out:
# Saved model: artifacts_3_classes/action_lstm.keras
# Saved weights: artifacts_3_classes/action_lstm_v1.weights.h5
# Saved meta: artifacts/meta.json and artifacts/classes.npy
# INFO:tensorflow:Assets written to: /var/folders/rq/z0dms6ss09q4h5llkdn9c10w0000gn/T/tmpt4f82aid/assets
# INFO:tensorflow:Assets written to: /var/folders/rq/z0dms6ss09q4h5llkdn9c10w0000gn/T/tmpt4f82aid/assets
# Saved artifact at '/var/folders/rq/z0dms6ss09q4h5llkdn9c10w0000gn/T/tmpt4f82aid'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 258), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   5906778064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910806992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910808336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910808720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910807760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910809296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910809104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910808528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910807184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910809488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910810832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5910810640: TensorSpec(shape=(), dtype=tf.resource, name=None)
# [WARN] TFLite export skipped: Could not translate MLIR to FlatBuffer.<unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): see current operation: %1:5 = "tf.CudnnRNNV3"(%arg0, %arg1, %arg2, %arg3, %arg4) {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x60x258xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<198656xf32>, tensor<?xi32>) -> (tensor<?x60x128xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<*xf32>, tensor<*xi8>)
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1_2/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1_2/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): see current operation: %1:5 = "tf.CudnnRNNV3"(%arg0, %arg1, %arg2, %arg3, %arg4) {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x60x128xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<49664xf32>, tensor<?xi32>) -> (tensor<?x60x64xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<*xf32>, tensor<*xi8>)
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1_2/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: failed while converting: 'main':
# Some ops in the model are custom ops, See instructions to implement custom ops: https://www.tensorflow.org/lite/guide/ops_custom
# Custom ops: CudnnRNNV3
# Details:
# 	tf.CudnnRNNV3(tensor<?x60x128xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<49664xf32>, tensor<?xi32>) -> (tensor<?x60x64xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# 	tf.CudnnRNNV3(tensor<?x60x258xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<198656xf32>, tensor<?xi32>) -> (tensor<?x60x128xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
#
# <unknown>:0: note: see current operation:
# "func.func"() <{arg_attrs = [{tf_saved_model.index_path = ["input_layer"]}], function_type = (tensor<?x60x258xf32>) -> tensor<?x3xf32>, res_attrs = [{tf_saved_model.index_path = ["output_0"]}], sym_name = "main"}> ({
# ^bb0(%arg0: tensor<?x60x258xf32>):
#   %0 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<3x128xf32>}> : () -> tensor<3x128xf32>
#   %1 = "arith.constant"() <{value = dense<[-0.023106128, -0.119022772, 0.087966226]> : tensor<3xf32>}> : () -> tensor<3xf32>
#   %2 = "arith.constant"() <{value = dense<[-1, 64]> : tensor<2xi32>}> : () -> tensor<2xi32>
#   %3 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<128x64xf32>}> : () -> tensor<128x64xf32>
#   %4 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<128xf32>}> : () -> tensor<128xf32>
#   %5 = "arith.constant"() <{value = dense<60> : tensor<i32>}> : () -> tensor<i32>
#   %6 = "arith.constant"() <{value = dense<1> : tensor<i32>}> : () -> tensor<i32>
#   %7 = "arith.constant"() <{value = dense<0> : tensor<1xi32>}> : () -> tensor<1xi32>
#   %8 = "arith.constant"() <{value = dense<1> : tensor<1xi32>}> : () -> tensor<1xi32>
#   %9 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<f32>}> : () -> tensor<f32>
#   %10 = "arith.constant"() <{value = dense<128> : tensor<i32>}> : () -> tensor<i32>
#   %11 = "arith.constant"() <{value = dense<64> : tensor<i32>}> : () -> tensor<i32>
#   %12 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<49664xf32>}> : () -> tensor<49664xf32>
#   %13 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<198656xf32>}> : () -> tensor<198656xf32>
#   %14 = "tfl.shape"(%arg0) : (tensor<?x60x258xf32>) -> tensor<3xi32>
#   %15 = "tfl.strided_slice"(%14, %7, %8, %8) <{begin_mask = 0 : i32, ellipsis_mask = 0 : i32, end_mask = 0 : i32, new_axis_mask = 0 : i32, offset = false, shrink_axis_mask = 1 : i32}> : (tensor<3xi32>, tensor<1xi32>, tensor<1xi32>, tensor<1xi32>) -> tensor<i32>
#   %16 = "tfl.pack"(%15, %10) <{axis = 0 : i32, values_count = 2 : i32}> : (tensor<i32>, tensor<i32>) -> tensor<2xi32>
#   %17 = "tfl.fill"(%16, %9) : (tensor<2xi32>, tensor<f32>) -> tensor<?x128xf32>
#   %18 = "tfl.expand_dims"(%17, %6) : (tensor<?x128xf32>, tensor<i32>) -> tensor<?x1x128xf32>
#   %19 = "tfl.reshape"(%15, %8) : (tensor<i32>, tensor<1xi32>) -> tensor<1xi32>
#   %20 = "tfl.fill"(%19, %5) : (tensor<1xi32>, tensor<i32>) -> tensor<?xi32>
#   %21:5 = "tfl.custom_tf"(%arg0, %18, %18, %13, %20) ({
#   ^bb0(%arg6: tensor<?x60x258xf32>, %arg7: tensor<?x1x128xf32>, %arg8: tensor<?x1x128xf32>, %arg9: tensor<198656xf32>, %arg10: tensor<?xi32>):
#     %35:5 = "tf.CudnnRNNV3"(%arg6, %arg7, %arg8, %arg9, %arg10) {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x60x258xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<198656xf32>, tensor<?xi32>) -> (tensor<?x60x128xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<*xf32>, tensor<*xi8>)
#     "tfl.yield"(%35#0, %35#1, %35#2, %35#3, %35#4) : (tensor<?x60x128xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<*xf32>, tensor<*xi8>) -> ()
#   }) {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x60x258xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<198656xf32>, tensor<?xi32>) -> (tensor<?x60x128xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<*xf32>, tensor<*xi8>)
#   %22 = "tfl.shape"(%21#0) : (tensor<?x60x128xf32>) -> tensor<3xi32>
#   %23 = "tfl.strided_slice"(%22, %7, %8, %8) <{begin_mask = 0 : i32, ellipsis_mask = 0 : i32, end_mask = 0 : i32, new_axis_mask = 0 : i32, offset = false, shrink_axis_mask = 1 : i32}> : (tensor<3xi32>, tensor<1xi32>, tensor<1xi32>, tensor<1xi32>) -> tensor<i32>
#   %24 = "tfl.pack"(%23, %11) <{axis = 0 : i32, values_count = 2 : i32}> : (tensor<i32>, tensor<i32>) -> tensor<2xi32>
#   %25 = "tfl.fill"(%24, %9) : (tensor<2xi32>, tensor<f32>) -> tensor<?x64xf32>
#   %26 = "tfl.expand_dims"(%25, %6) : (tensor<?x64xf32>, tensor<i32>) -> tensor<?x1x64xf32>
#   %27 = "tfl.reshape"(%23, %8) : (tensor<i32>, tensor<1xi32>) -> tensor<1xi32>
#   %28 = "tfl.fill"(%27, %5) : (tensor<1xi32>, tensor<i32>) -> tensor<?xi32>
#   %29:5 = "tfl.custom_tf"(%21#0, %26, %26, %12, %28) ({
#   ^bb0(%arg1: tensor<?x60x128xf32>, %arg2: tensor<?x1x64xf32>, %arg3: tensor<?x1x64xf32>, %arg4: tensor<49664xf32>, %arg5: tensor<?xi32>):
#     %34:5 = "tf.CudnnRNNV3"(%arg1, %arg2, %arg3, %arg4, %arg5) {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x60x128xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<49664xf32>, tensor<?xi32>) -> (tensor<?x60x64xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<*xf32>, tensor<*xi8>)
#     "tfl.yield"(%34#0, %34#1, %34#2, %34#3, %34#4) : (tensor<?x60x64xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<*xf32>, tensor<*xi8>) -> ()
#   }) {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x60x128xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<49664xf32>, tensor<?xi32>) -> (tensor<?x60x64xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<*xf32>, tensor<*xi8>)
#   %30 = "tfl.reshape"(%29#1, %2) : (tensor<?x1x64xf32>, tensor<2xi32>) -> tensor<?x64xf32>
#   %31 = "tfl.fully_connected"(%30, %3, %4) <{fused_activation_function = "RELU", keep_num_dims = false, weights_format = "DEFAULT"}> : (tensor<?x64xf32>, tensor<128x64xf32>, tensor<128xf32>) -> tensor<?x128xf32>
#   %32 = "tfl.fully_connected"(%31, %0, %1) <{fused_activation_function = "NONE", keep_num_dims = false, weights_format = "DEFAULT"}> : (tensor<?x128xf32>, tensor<3x128xf32>, tensor<3xf32>) -> tensor<?x3xf32>
#   %33 = "tfl.softmax"(%32) <{beta = 1.000000e+00 : f32}> : (tensor<?x3xf32>) -> tensor<?x3xf32>
#   "func.return"(%33) : (tensor<?x3xf32>) -> ()
# }) {tf.entry_function = {control_outputs = "", inputs = "serving_default_input_layer:0", outputs = "StatefulPartitionedCall_1:0"}, tf_saved_model.exported_names = ["serving_default"]} : () -> ()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1761659188.296565 69859699 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1761659188.296886 69859699 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1761659188.303790 69859699 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# loc(callsite(callsite(fused["CudnnRNNV3:", "functional_1/lstm_1_2/CudnnRNNV3@__inference_function_112699"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_112766"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# error: failed while converting: 'main':
# Some ops in the model are custom ops, See instructions to implement custom ops: https://www.tensorflow.org/lite/guide/ops_custom
# Custom ops: CudnnRNNV3
# Details:
# 	tf.CudnnRNNV3(tensor<?x60x128xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<49664xf32>, tensor<?xi32>) -> (tensor<?x60x64xf32>, tensor<?x1x64xf32>, tensor<?x1x64xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# 	tf.CudnnRNNV3(tensor<?x60x258xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<198656xf32>, tensor<?xi32>) -> (tensor<?x60x128xf32>, tensor<?x1x128xf32>, tensor<?x1x128xf32>, tensor<*xf32>, tensor<*xi8>) : {T = f32, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "lstm", seed = 0 : i64, seed2 = 0 : i64, time_major = false}

# %% [markdown]
# ## 5. Evalutation

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import tensorflow as tf
from sklearn.metrics import (
    confusion_matrix, classification_report, accuracy_score, roc_auc_score
)

ARTIFACTS = Path("artifacts_3_classes")
MODEL_PATH = ARTIFACTS / "action_lstm.keras"

# --- Load best model ---
if not MODEL_PATH.exists():
    raise FileNotFoundError(f"{MODEL_PATH} not found. Train in Section 7 first.")
model = tf.keras.models.load_model(str(MODEL_PATH))

# --- Ensure datasets are available (from memory or disk) ---
def load_split(name):
    varX, vary = f"X_{name}", f"y_{name}"
    if varX in globals() and vary in globals():
        return globals()[varX], globals()[vary]
    data = np.load(ARTIFACTS / f"dataset_{name}.npz")
    return data["X"], data["y"]

X_train, y_train = load_split("train")
X_val,   y_val   = load_split("val")
X_test,  y_test  = load_split("test")

# Class names
if "classes" in globals():
    class_names = list(classes)
else:
    class_names = [f"class_{i}" for i in range(y_train.shape[1])]
num_classes = len(class_names)

def evaluate_split(X, y, split_name: str):
    """Predict, print metrics, save confusion matrices (raw & normalized), and plot."""
    # Predict
    probs = model.predict(X.astype(np.float32), verbose=0)          # (N, C)
    y_pred = probs.argmax(axis=1)
    y_true = y.argmax(axis=1)

    # Accuracy & report
    acc = accuracy_score(y_true, y_pred)
    print(f"\n=== {split_name.upper()} ===")
    print(f"Accuracy: {acc:.4f}")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    # Confusion matrices
    labels = np.arange(num_classes)
    cm = confusion_matrix(y_true, y_pred, labels=labels)            # raw counts
    with np.errstate(invalid="ignore", divide="ignore"):
        cm_norm = cm.astype(np.float64) / cm.sum(axis=1, keepdims=True).clip(min=1)  # row-normalized

    # Save CSVs
    np.savetxt(ARTIFACTS / f"{split_name}_cm.csv", cm, fmt="%d", delimiter=",")
    np.savetxt(ARTIFACTS / f"{split_name}_cm_norm.csv", cm_norm, fmt="%.6f", delimiter=",")

    # Plot normalized confusion matrix
    fig, ax = plt.subplots(figsize=(5.5, 4.5), dpi=140)
    im = ax.imshow(cm_norm, interpolation="nearest")
    ax.figure.colorbar(im, ax=ax)
    ax.set(
        xticks=np.arange(num_classes), yticks=np.arange(num_classes),
        xticklabels=class_names, yticklabels=class_names,
        ylabel="True label", xlabel="Predicted label",
        title=f"{split_name.title()} Confusion Matrix (row-normalized)"
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Annotate cells
    thresh = np.nanmax(cm_norm) / 2.0 if np.isfinite(cm_norm).any() else 0.5
    for i in range(num_classes):
        for j in range(num_classes):
            val = cm_norm[i, j] if np.isfinite(cm_norm[i, j]) else 0.0
            ax.text(j, i, f"{val:.2f}", ha="center", va="center",
                    color="white" if val > thresh else "black")
    fig.tight_layout()
    out_png = ARTIFACTS / f"{split_name}_cm.png"
    fig.savefig(out_png, bbox_inches="tight")
    plt.show()

    # Binary ROC-AUC (optional, only if 2 classes)
    if num_classes == 2:
        try:
            auc = roc_auc_score(y_true, probs[:, 1])
            print(f"ROC-AUC: {auc:.4f}")
        except Exception as e:
            print(f"[WARN] ROC-AUC skipped: {e}")

    return acc, cm, cm_norm

# Evaluate all splits
train_acc, train_cm, train_cm_norm = evaluate_split(X_train, y_train, "train")
val_acc,   val_cm,   val_cm_norm   = evaluate_split(X_val,   y_val,   "val")
test_acc,  test_cm,  test_cm_norm  = evaluate_split(X_test,  y_test,  "test")

print("\nSaved CSV and PNG confusion matrices under:", ARTIFACTS.resolve())
# Out:
# === TRAIN ===
# Accuracy: 0.8611
#               precision    recall  f1-score   support
#
#        Bedok     1.0000    1.0000    1.0000        24
#    City Hall     1.0000    0.5833    0.7368        24
#          MBS     0.7059    1.0000    0.8276        24
#
#     accuracy                         0.8611        72
#    macro avg     0.9020    0.8611    0.8548        72
# weighted avg     0.9020    0.8611    0.8548        72
# === VAL ===
# Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#        Bedok     1.0000    1.0000    1.0000         3
#    City Hall     1.0000    1.0000    1.0000         3
#          MBS     1.0000    1.0000    1.0000         3
#
#     accuracy                         1.0000         9
#    macro avg     1.0000    1.0000    1.0000         9
# weighted avg     1.0000    1.0000    1.0000         9
# === TEST ===
# Accuracy: 0.7778
#               precision    recall  f1-score   support
#
#        Bedok     1.0000    1.0000    1.0000         3
#    City Hall     1.0000    0.3333    0.5000         3
#          MBS     0.6000    1.0000    0.7500         3
#
#     accuracy                         0.7778         9
#    macro avg     0.8667    0.7778    0.7500         9
# weighted avg     0.8667    0.7778    0.7500         9
# Saved CSV and PNG confusion matrices under: /Users/sritampatnaik/Masters/NUS-ISS Sritam/NUS-ISS Sem 2/Project/sign-lang/artifacts_3_classes
